# %%
import pandas as pandas

# %%
pandas.__version__
# Out:
# '0.23.0'

# %%
pwd
# Out:
# 'D:\\Data Science\\Python\\Titanic Python'

# %%
import os
os.chdir('D:\Data Science\Python\Titanic Python')

# %%
train = pandas.read_csv('D:\\Data Science\\Python\\Titanic Python\\train.csv')
test = pandas.read_csv('D:\\Data Science\\Python\\Titanic Python\\test.csv')

# %%
train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train.shape
# Out:
# (891, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    891 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.6+ KB

# %%
train['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
train['SibSp'].head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# Name: SibSp, dtype: int64

# %%
train[['Name','SibSp','Parch']].head()
# Out:
#                                                 Name  SibSp  Parch
# 0                            Braund, Mr. Owen Harris      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 2                             Heikkinen, Miss. Laina      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# 4                           Allen, Mr. William Henry      0      0

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.loc[0:14]
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
train.iloc[-1]
# Out:
# Survived                      0
# Pclass                        3
# Name        Dooley, Mr. Patrick
# Sex                        male
# Age                          32
# SibSp                         0
# Parch                         0
# Ticket                   370376
# Fare                       7.75
# Cabin                       NaN
# Embarked                      Q
# Name: 890, dtype: object

# %%
train.loc[890]
# Out:
# Survived                      0
# Pclass                        3
# Name        Dooley, Mr. Patrick
# Sex                        male
# Age                          32
# SibSp                         0
# Parch                         0
# Ticket                   370376
# Fare                       7.75
# Cabin                       NaN
# Embarked                      Q
# Name: 890, dtype: object

# %%
train.loc[0:4]
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
train['Fare'].mean()
# Out:
# 32.2042079685746

# %%
Mean = train['Age'].mean()

# %%
train.loc[train['Age']>Mean,:]
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 6           0       1                            McCarthy, Mr. Timothy J
# 11          1       1                           Bonnell, Miss. Elizabeth
# 13          0       3                        Andersson, Mr. Anders Johan
# 15          1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 18          0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20          0       2                               Fynney, Mr. Joseph J
# 21          1       2                              Beesley, Mr. Lawrence
# 25          1       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 30          0       1                           Uruchurtu, Don. Manuel E
# ...

# %%
Mean = train.groupby('Sex')['Age'].mean()
Median = train.groupby('Sex')['Age'].median()

# %%
 Mean
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
Median
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
print(train.boxplot('Age'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df = train.groupby('Survived')[['Sex','Age']].mean()

# %%
df
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
train.groupby('Age')[['Pclass','Embarked']].nunique()
# Out:
#        Pclass  Embarked
# Age
# 0.42        1         1
# 0.67        1         1
# 0.75        1         1
# 0.83        1         1
# 0.92        1         1
# 1.00        2         2
# 2.00        3         2
# 3.00        2         2
# 4.00        3         3
# 5.00        2         2
# 6.00        2         1
# 7.00        2         2
# 8.00        2         2
# 9.00        1         2
# 10.00       1         1
# 11.00       2         2
# 12.00       1         1
# 13.00       2         2
# 14.00       3         2
# 14.50       1         1
# 15.00       2         3
# 16.00       3         3
# 17.00       3         2
# 18.00       3         3
# 19.00       3         3
# 20.00       1         2
# 20.50       1         1
# 21.00       3         3
# 22.00       3         3
# 23.00       3         2
# ...       ...       ...
# 44.00       3         3
# 45.00       3         2
# 45.50       2         2
# 46.00       2         2
# 47.00       3         1
# 48.00       3         2
# ...

# %%
data = train.groupby('Survived')['Pclass'].value_counts()

# %%
import matplotlib as graph
# %matplotlib inline
data.plot()
data
# Out:
# Survived  Pclass
# 0         3         372
#           2          97
#           1          80
# 1         1         136
#           3         119
#           2          87
# Name: Pclass, dtype: int64

# %%
data
# Out:
# Survived  Pclass
# 0         3         372
#           2          97
#           1          80
# 1         1         136
#           3         119
#           2          87
# Name: Pclass, dtype: int64

# %%
data = train.groupby('Survived')['Sex'].value_counts()

# %%
data
# Out:
# Survived  Sex
# 0         male      468
#           female     81
# 1         female    233
#           male      109
# Name: Sex, dtype: int64

# %%
datareset = train.groupby('Age')[['Pclass','Embarked']].nunique()

# %%
datareset = datareset.reset_index()

# %%
datareset
# Out:
#       Age  Pclass  Embarked
# 0    0.42       1         1
# 1    0.67       1         1
# 2    0.75       1         1
# 3    0.83       1         1
# 4    0.92       1         1
# 5    1.00       2         2
# 6    2.00       3         2
# 7    3.00       2         2
# 8    4.00       3         3
# 9    5.00       2         2
# 10   6.00       2         1
# 11   7.00       2         2
# 12   8.00       2         2
# 13   9.00       1         2
# 14  10.00       1         1
# 15  11.00       2         2
# 16  12.00       1         1
# 17  13.00       2         2
# 18  14.00       3         2
# 19  14.50       1         1
# 20  15.00       2         3
# 21  16.00       3         3
# 22  17.00       3         2
# 23  18.00       3         3
# 24  19.00       3         3
# 25  20.00       1         2
# 26  20.50       1         1
# 27  21.00       3         3
# 28  22.00       3         3
# 29  23.00       3         2
# ..    ...     ...       ...
# 58  44.00       3         3
# ...

# %%
datareset.to_csv("D:\Data Science\Python\Titanic Python\datareset.csv", index = False)

# %%
test[1:40]
# Out:
#    Survived  Pclass                                               Name  \
# 1       TBC       3                   Wilkes, Mrs. James (Ellen Needs)
# 2       TBC       2                          Myles, Mr. Thomas Francis
# 3       TBC       3                                   Wirz, Mr. Albert
# 4       TBC       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5       TBC       3                         Svensson, Mr. Johan Cervin
# 6       TBC       3                               Connolly, Miss. Kate
# 7       TBC       2                       Caldwell, Mr. Albert Francis
# 8       TBC       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9       TBC       3                            Davies, Mr. John Samuel
# 10      TBC       3                                   Ilieff, Mr. Ylio
# 11      TBC       1                         Jones, Mr. Charles Cresson
# 12      TBC       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# ...

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
from numpy import NaN, NAN, nan

# %%
train['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 861    False
# 862    False
# 863     True
# 864    False
# 865    False
# 866    False
# 867    False
# 868     True
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878     True
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
Combined = pandas.concat([train,test])

# %%
Combined['Age'].value_counts(dropna = False).head()
# Out:
# NaN      263
#  24.0     47
#  22.0     43
#  21.0     41
#  30.0     40
# Name: Age, dtype: int64

# %%
Combined['Survived'].nunique()
# Out:
# 3

# %%
Combined['Survived'].unique()
# Out:
# array([0, 1, 'TBC'], dtype=object)
